# %%
import numpy as np

# %%
test_input = np.load('test_input.npy')
test_output = np.load('test_output.npy')

train_input = np.load('train_input.npy')
train_output = np.load('train_output.npy')

# %%
print("Test input shape:", test_input.shape)
print("Test output shape:", test_output.shape)
# Out:
# Test input shape: (8000, 512)
# Test output shape: (8000, 512)

# %%
print("Training input shape:", train_input.shape)
print("Training output shape:", train_output.shape)
# Out:
# Training input shape: (60000, 512)
# Training output shape: (60000, 512)

# %%
import matplotlib.pyplot as plt

def plot(eeg_data, title):
    """Plot EEG data with proper time axis."""
    sampling_frequency = 256  # Hz - adjust based on your data
    num_samples = len(eeg_data)
    time_duration = num_samples / sampling_frequency  # seconds
    time = np.linspace(0, time_duration, num_samples, endpoint=False)

    plt.figure(figsize=(12, 5))
    plt.plot(time, eeg_data)
    plt.title(title)
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude (normalized)')
    plt.grid(True)
    plt.show()

# %%
plot(test_input[0], "Test Input Sample 0")
plot(test_output[0], "Test Output Sample 0")
